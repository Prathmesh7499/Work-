# %%
import requests
import json
import pandas as pd

# %%
data = requests.get("https://web.archive.org/web/20240929211114/https://fruityvice.com/api/fruit/all")

# %%
results = json.loads(data.text)

# %%
pd.DataFrame(results)

df = pd.json_normalize(results)
df
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %%
import pandas as pd
URL = 'https://en.wikipedia.org/wiki/List_of_largest_banks'
tables = pd.read_html(URL)
df = tables[0]
pd.DataFrame(df)


df = df.iloc[1:21,:]
df
# Out:
#     Rank                       Bank name  Total assets (2023) (US$ billion)
# 1      2      Agricultural Bank of China                            5623.12
# 2      3         China Construction Bank                            5400.28
# 3      4                   Bank of China                            4578.28
# 4      5                  JPMorgan Chase                            3875.39
# 5      6                 Bank of America                            3180.15
# 6      7                            HSBC                            2919.84
# 7      8                     BNP Paribas                            2867.44
# 8      9  Mitsubishi UFJ Financial Group                            2816.77
# 9     10                 Crédit Agricole                            2736.95
# 10    11    Postal Savings Bank of China                            2217.86
# 11    12                       Citigroup                            2200.83
# ...

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_banks#Banks_by_country_or_territory'
tbale1 = pd.read_html(url)
df1 = tables[0]
df1.iloc[1:33,:]
# Out:
#     Rank                         Bank name  Total assets (2023) (US$ billion)
# 1      2        Agricultural Bank of China                            5623.12
# 2      3           China Construction Bank                            5400.28
# 3      4                     Bank of China                            4578.28
# 4      5                    JPMorgan Chase                            3875.39
# 5      6                   Bank of America                            3180.15
# 6      7                              HSBC                            2919.84
# 7      8                       BNP Paribas                            2867.44
# 8      9    Mitsubishi UFJ Financial Group                            2816.77
# 9     10                   Crédit Agricole                            2736.95
# 10    11      Postal Savings Bank of China                            2217.86
# 11    12                         Citigroup                            2200.83
# ...

# %% [markdown]
# ### Scraping List of prime ministers of India from Wikipedia

# %%
url1 = 'https://en.wikipedia.org/wiki/List_of_prime_ministers_of_India'
table3 = pd.read_html(url1)
df3 = table3[2]


df3
# Out:
#    No.                     Name              Party          Length of term  \
#    No.                     Name              Party Longest continuous term
# 0    1         Jawaharlal Nehru                INC      16 years, 286 days
# 1    2            Indira Gandhi  INC/INC(I)/INC(R)       11 years, 59 days
# 2    3            Narendra Modi                BJP      10 years, 236 days
# 3    4           Manmohan Singh                INC        10 years, 4 days
# 4    5     Atal Bihari Vajpayee                BJP        6 years, 64 days
# 5    6             Rajiv Gandhi             INC(I)        5 years, 32 days
# 6    7      P. V. Narasimha Rao             INC(I)       4 years, 330 days
# 7    8            Morarji Desai                 JP       2 years, 126 days
# 8    9      Lal Bahadur Shastri                INC        1 year, 216 days
# 9   10  Vishwanath Pratap Singh                 JD                343 days
# ...
